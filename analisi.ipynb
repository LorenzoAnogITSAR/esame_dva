# %%
import pandas as pd

# %%
df = pd.read_csv(r"data\vgsales_clean.csv")

# %%
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0          Nintendo     41.36     28.96      3.77         8.45         82.53
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 2          Nintendo     15.68     12.76      3.79         3.29         35.52
# 3          Nintendo     15.61     10.93      3.28         2.95         32.77
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# ...             ...       ...       ...       ...          ...           ...
# 16714    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16715   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16716  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16717       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        Critic_Score  Critic_Count User_Score  User_Count Developer Rating
# 0              76.0          51.0          8       322.0  Nintendo      E
# 1               NaN           NaN        NaN         NaN       NaN    NaN
# 2              82.0          73.0        8.3       709.0  Nintendo      E
# 3              80.0          73.0          8       192.0  Nintendo      E
# 4               NaN           NaN        NaN         NaN       NaN    NaN
# ...             ...           ...        ...         ...       ...    ...
# 16714           NaN           NaN        NaN         NaN       NaN    NaN
# 16715           NaN           NaN        NaN         NaN       NaN    NaN
# 16716           NaN           NaN        NaN         NaN       NaN    NaN
# 16717           NaN           NaN        NaN         NaN       NaN    NaN
# 16718           NaN           NaN        NaN         NaN       NaN    NaN
#
# [16719 rows x 16 columns]

# %%
df['Name'][df['Year_of_Release'] > 2016]
# Out:
# 5936     0.29
# 14086    0.04
# 16222    0.01
# 16385    0.01
# Name: Global_Sales, dtype: float64

# %%
df.iloc[14086]
# Out:
# Name               Phantasy Star Online 2 Episode 4: Deluxe Package
# Platform                                                        PS4
# Year_of_Release                                              2017.0
# Genre                                                  Role-Playing
# Publisher                                                      Sega
# NA_Sales                                                        0.0
# EU_Sales                                                        0.0
# JP_Sales                                                       0.04
# Other_Sales                                                     0.0
# Global_Sales                                                   0.04
# Critic_Score                                                    NaN
# Critic_Count                                                    NaN
# User_Score                                                      NaN
# User_Count                                                      NaN
# Developer                                                       NaN
# Rating                                                          NaN
# Name: 14086, dtype: object

# %%
df['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy', nan], dtype=object)

# %%
df[df['Year_of_Release'] > 2016]
# Out:
#                                                    Name Platform  \
# 5936                             Imagine: Makeup Artist       DS
# 14086  Phantasy Star Online 2 Episode 4: Deluxe Package      PS4
# 16222  Phantasy Star Online 2 Episode 4: Deluxe Package      PSV
# 16385                  Brothers Conflict: Precious Baby      PSV
#
#        Year_of_Release         Genre     Publisher  NA_Sales  EU_Sales  \
# 5936            2020.0    Simulation       Ubisoft      0.27       0.0
# 14086           2017.0  Role-Playing          Sega      0.00       0.0
# 16222           2017.0  Role-Playing          Sega      0.00       0.0
# 16385           2017.0        Action  Idea Factory      0.00       0.0
#
#        JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 5936       0.00         0.02          0.29           NaN           NaN
# 14086      0.04         0.00          0.04           NaN           NaN
# 16222      0.01         0.00          0.01           NaN           NaN
# 16385      0.01         0.00          0.01           NaN           NaN
#
#       User_Score  User_Count Developer Rating
# 5936         tbd         NaN   Ubisoft      E
# 14086        NaN         NaN       NaN    NaN
# 16222        NaN         NaN       NaN    NaN
# 16385        NaN         NaN       NaN    NaN

# %%
df_pulito = df[df['Year_of_Release'] < 2016]

# %%
df_pulito[df_pulito['Year_of_Release'] > 2014]
# Out:
#                                                     Name Platform  \
# 31                             Call of Duty: Black Ops 3      PS4
# 77                                               FIFA 16      PS4
# 87                          Star Wars Battlefront (2015)      PS4
# 99                             Call of Duty: Black Ops 3     XOne
# 105                                            Fallout 4      PS4
# ...                                                  ...      ...
# 16601                        Saints Row: Gat out of Hell     XOne
# 16612  Mario & Luigi: Paper Jam & Mario Kart 7 Double...      3DS
# 16614                                  Kiniro no Corda 3      3DS
# 16622                              Xblaze: Lost Memories      PSV
# 16666                Hakuoki: Reimeiroku - Omouhase Kara      PSV
#
#        Year_of_Release         Genre           Publisher  NA_Sales  EU_Sales  \
# 31              2015.0       Shooter          Activision      6.03      5.86
# 77              2015.0        Sports     Electronic Arts      1.12      6.12
# 87              2015.0       Shooter     Electronic Arts      2.99      3.49
# 99              2015.0       Shooter          Activision      4.59      2.11
# 105             2015.0  Role-Playing  Bethesda Softworks      2.53      3.27
# ...                ...           ...                 ...       ...       ...
# 16601           2015.0        Action         Deep Silver      0.00      0.01
# 16612           2015.0          Misc            Nintendo      0.00      0.00
# 16614           2015.0     Adventure          Tecmo Koei      0.00      0.00
# 16622           2015.0     Adventure    Arc System Works      0.01      0.00
# 16666           2015.0        Action        Idea Factory      0.00      0.00
#
#        JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 31         0.36         2.38         14.63           NaN           NaN
# 77         0.06         1.28          8.57          82.0          42.0
# 87         0.22         1.28          7.98           NaN           NaN
# 99         0.01         0.68          7.39           NaN           NaN
# 105        0.24         1.13          7.16          87.0          58.0
# ...         ...          ...           ...           ...           ...
# 16601      0.00         0.00          0.01          65.0          16.0
# 16612      0.01         0.00          0.01           NaN           NaN
# 16614      0.01         0.00          0.01           NaN           NaN
# 16622      0.00         0.00          0.01           NaN           NaN
# 16666      0.01         0.00          0.01           NaN           NaN
#
#       User_Score  User_Count              Developer Rating
# 31           NaN         NaN                    NaN    NaN
# 77           4.3       896.0              EA Sports      E
# 87           NaN         NaN                    NaN    NaN
# 99           NaN         NaN                    NaN    NaN
# 105          6.5      4228.0  Bethesda Game Studios      M
# ...          ...         ...                    ...    ...
# 16601          6        27.0          Volition Inc.      M
# 16612        NaN         NaN                    NaN    NaN
# 16614        NaN         NaN                    NaN    NaN
# 16622          7         8.0       Arc System Works      M
# 16666        NaN         NaN                    NaN    NaN
#
# [606 rows x 16 columns]

# %%
df_pulito.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release       0
# Genre                 2
# Publisher            30
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8193
# Critic_Count       8193
# User_Score         6401
# User_Count         8743
# Developer          6350
# Rating             6456
# dtype: int64
